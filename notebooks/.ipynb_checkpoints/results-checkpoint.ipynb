# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
import re
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## Accuracy

# %%
level = 6
source_file = '../output/random_s_level_{}.txt'.format(level)
cg_file = '../output/random_with_memory/result_cg_{}'.format(level)
syl_file = '../output/random_with_memory/result_syl_{}'.format(level)

def read_result_file(result_file):
    with open(result_file, "r") as f:
        data = f.read()
        result = [float(x) for x in data[1:-1].split(" ")]
    return np.array(result)

source_vector = np.loadtxt(source_file, delimiter=",")
cg_vector = read_result_file(cg_file)
syl_vector = read_result_file(syl_file)

# %%
df = pd.DataFrame(data={'Source': source_vector, 'Conjugate Gradient': cg_vector, 'Sylvester': syl_vector})

# %%
plt.rcParams["figure.figsize"] = (10,10)
# Plot a simple line chart
plt.errorbar(df['Source'], df['Conjugate Gradient'], color='b', label='Conjugate Gradient Result', marker='o', linestyle='dashed')

# Plot another line on the same chart/graph
plt.errorbar(df['Source'], df['Sylvester'], color='r', label='Sylvester Method Result', marker='*', linestyle='dotted')

plt.xlabel('Source Vector, h=4, N=3072')
plt.legend()
plt.show()

# %% [markdown]
# ## Time cost

# %%
df_cost = pd.read_csv('time_and_memory.csv')
df_cost['N'] = df_cost.apply(lambda row: (4**int(row['level'])) * 12, axis=1)

# %%
sns.lineplot(data=df_cost, 
             x='N', y='time', hue='method', style='data')
# Out:
# <AxesSubplot:xlabel='N', ylabel='time'>

# %%
sns.lineplot(data=df_cost, 
             x='N', y='memory', hue='method', style='data')
# Out:
# <AxesSubplot:xlabel='N', ylabel='memory'>

# %% [markdown]
# ## Profiling

# %%
def get_profiling_file(ptype, algo, level):
    profiling_folder = '../output/profiling/'
    file_name = f"{ptype}_{algo}_planck_{level}.txt"
    return profiling_folder + file_name

# %%
# Example of a profiling file
file_path = get_profiling_file('time', 'cg', 4)
with open(file_path) as f:
    print(f.read())
# Out:
# File: cmbsolution
# Type: cpu
# Time: Dec 15, 2021 at 3:49pm (GMT)
# Duration: 210.30ms, Total samples = 180ms (85.59%)
# Showing nodes accounting for 180ms, 100% of 180ms total
#       flat  flat%   sum%        cum   cum%
#       40ms 22.22% 22.22%       40ms 22.22%  runtime.pthread_cond_wait
#       30ms 16.67% 38.89%       30ms 16.67%  runtime.usleep
#       20ms 11.11% 50.00%       20ms 11.11%  runtime.kevent
#       20ms 11.11% 61.11%       20ms 11.11%  runtime.pthread_cond_signal
#       10ms  5.56% 66.67%       10ms  5.56%  aeshashbody
#       10ms  5.56% 72.22%       10ms  5.56%  runtime.(*bmap).overflow (inline)
#       10ms  5.56% 77.78%       10ms  5.56%  runtime.(*spanSet).push
#       10ms  5.56% 83.33%       90ms 50.00%  runtime.findrunnable
#       10ms  5.56% 88.89%       10ms  5.56%  runtime.gcWriteBarrier
#       10ms  5.56% 94.44%       10ms  5.56%  runtime.madvise
#       10ms  5.56%   100%       20ms 11.11%  runtime.mapassign_faststr
#          0     0%   100%       40ms 22.22%  conjugate/solu.(*DXOpe).cal
#          0     0%   100%       20ms 11.11%  conjugate/solu.findNeighbors (inline)
#          0     0%   100%       10ms  5.56%  gonum.org/v1/gonum/blas/gonum.dgemmParallel.func1
#          0     0%   100%       10ms  5.56%  runtime.(*mspan).sweep
#          0     0%   100%       10ms  5.56%  runtime.(*pageAlloc).scavenge
#          0     0%   100%       10ms  5.56%  runtime.(*pageAlloc).scavengeOne
#          0     0%   100%       10ms  5.56%  runtime.(*pageAlloc).scavengeRangeLocked
#          0     0%   100%       10ms  5.56%  runtime.bgscavenge.func2
#          0     0%   100%       10ms  5.56%  runtime.bgsweep
#          0     0%   100%       10ms  5.56%  runtime.chanrecv
#          0     0%   100%       10ms  5.56%  runtime.chanrecv2
#          0     0%   100%       90ms 50.00%  runtime.goexit0
#          0     0%   100%       30ms 16.67%  runtime.lock (inline)
#          0     0%   100%       30ms 16.67%  runtime.lock2
#          0     0%   100%       30ms 16.67%  runtime.lockWithRank (inline)
#          0     0%   100%       40ms 22.22%  runtime.mPark
#          0     0%   100%       20ms 11.11%  runtime.mapiternext
#          0     0%   100%       90ms 50.00%  runtime.mcall
#          0     0%   100%       30ms 16.67%  runtime.mstart
#          0     0%   100%       20ms 11.11%  runtime.netpoll
#          0     0%   100%       20ms 11.11%  runtime.newproc.func1
#          0     0%   100%       40ms 22.22%  runtime.notesleep
#          0     0%   100%       20ms 11.11%  runtime.notewakeup
#          0     0%   100%       30ms 16.67%  runtime.osyield (inline)
#          0     0%   100%       90ms 50.00%  runtime.schedule
#          0     0%   100%       40ms 22.22%  runtime.semasleep
#          0     0%   100%       20ms 11.11%  runtime.semawakeup
#          0     0%   100%       20ms 11.11%  runtime.startm
#          0     0%   100%       40ms 22.22%  runtime.stopm
#          0     0%   100%       10ms  5.56%  runtime.sweepone
#          0     0%   100%       10ms  5.56%  runtime.sysUnused (inline)
#          0     0%   100%       30ms 16.67%  runtime.systemstack
#          0     0%   100%       20ms 11.11%  runtime.wakep

# %%
df = pd.DataFrame(columns=['Type', 'Algorithm', 'Level', 'Flat', 'Flat%', 'Sum%', 'Cum', 'Cum%', 'Detail'])
for ptype in ['time', 'memory']:
    for algo in ['cg', 'syl']:
        for level in range(1, 11):
            file_path = get_profiling_file(ptype, algo, level)
            with open(file_path) as f:
                contents = f.readlines()
                for line in contents:
                    if line[0] == " " and line.strip()[0] != "f":
                        arr = line.strip().split()[:6]
                        row = [ptype, algo, level] + arr
                        df.loc[len(df)] = row
                    
print("Number of profiling instances: {}".format(df.shape[0]))
df.head()
# Out:
# Number of profiling instances: 1312
#    Type Algorithm Level  Flat   Flat%    Sum%   Cum    Cum%  \
# 0  time        cg     1  10ms  50.00%  50.00%  10ms  50.00%
# 1  time        cg     1  10ms  50.00%    100%  10ms  50.00%
# 2  time        cg     1     0      0%    100%  10ms  50.00%
# 3  time        cg     1     0      0%    100%  10ms  50.00%
# 4  time        cg     1     0      0%    100%  10ms  50.00%
#
#                          Detail
# 0               runtime.madvise
# 1                runtime.usleep
# 2  runtime.(*mheap).alloc.func1
# 3    runtime.(*mheap).allocSpan
# 4          runtime.findrunnable

# %%
# Format the numbers and percentages
def format_time(t):
    if t == "0":
        return float(0)
    else:
        if t[-2] in ['m', 'M', 'k']:
            return float(t[:-2])
        else:
            return float(t[:-1])
    
def format_percentage(p):
    return float(p[:-1])

# %%
df['Flat'] = df.apply(lambda row: format_time(row['Flat']), axis=1)
df['Flat%'] = df.apply(lambda row: format_percentage(row['Flat%']), axis=1)
df['Sum%'] = df.apply(lambda row: format_percentage(row['Sum%']), axis=1)
df['Cum'] = df.apply(lambda row: format_time(row['Cum']), axis=1)
df['Cum%'] = df.apply(lambda row: format_percentage(row['Cum%']), axis=1)

# %%
df.head()
# Out:
#    Type Algorithm Level  Flat  Flat%   Sum%   Cum  Cum%  \
# 0  time        cg     1  10.0   50.0   50.0  10.0  50.0
# 1  time        cg     1  10.0   50.0  100.0  10.0  50.0
# 2  time        cg     1   0.0    0.0  100.0  10.0  50.0
# 3  time        cg     1   0.0    0.0  100.0  10.0  50.0
# 4  time        cg     1   0.0    0.0  100.0  10.0  50.0
#
#                          Detail
# 0               runtime.madvise
# 1                runtime.usleep
# 2  runtime.(*mheap).alloc.func1
# 3    runtime.(*mheap).allocSpan
# 4          runtime.findrunnable

# %% [markdown]
# ### Conjugate Gradient

# %%
df_time = df[df['Type'] == 'time']
top3_commands = ['conjugate/solu.(*DXOpe).cal', 'conjugate/solu.(*IteSolu).calBtCBx', 'conjugate/solu.findNeighbors']
df_cg_time = df_time[(df_time['Algorithm'] == 'cg') & (df['Detail'].isin(top3_commands)) & (df['Level'] >= 4)]

# %%
sns.lineplot(data=df_cg_time, x='Level', y='Cum%', hue='Detail')
plt.ylabel("Percentage of time")
# Out:
# Text(0, 0.5, 'Percentage of time')

# %%
df_mem = df[df['Type'] == 'memory']
top_commands = ['conjugate/solu.(*IteSolu).FindSolution', 'conjugate/utils.LoadY']
df_cg_mem = df_mem[(df_mem['Algorithm'] == 'cg') & (df['Detail'].isin(top_commands)) & (df['Level'] >= 5)]

# %%
df_cg_mem
# Out:
#         Type Algorithm Level  Flat  Flat%    Sum%      Cum   Cum%  \
# 1126  memory        cg     6   0.0    0.0  100.00  1616.48  17.14
# 1127  memory        cg     6   0.0    0.0  100.00  3650.94  38.71
# 1141  memory        cg     7   0.0    0.0  100.00     6.00  15.72
# 1142  memory        cg     7   0.0    0.0  100.00    18.02  47.22
# 1152  memory        cg     8   0.0    0.0   99.65    24.00  16.86
# 1153  memory        cg     8   0.0    0.0   99.65    60.83  42.74
# 1163  memory        cg     9   0.0    0.0  100.00    96.00  11.32
# 1164  memory        cg     9   0.0    0.0  100.00   307.93  36.31
# 1182  memory        cg    10   0.0    0.0  100.00   384.00  16.29
# 1183  memory        cg    10   0.0    0.0  100.00  1039.25  44.09
#
#                                       Detail
# 1126  conjugate/solu.(*IteSolu).FindSolution
# 1127                   conjugate/utils.LoadY
# 1141  conjugate/solu.(*IteSolu).FindSolution
# 1142                   conjugate/utils.LoadY
# 1152  conjugate/solu.(*IteSolu).FindSolution
# 1153                   conjugate/utils.LoadY
# 1163  conjugate/solu.(*IteSolu).FindSolution
# 1164                   conjugate/utils.LoadY
# 1182  conjugate/solu.(*IteSolu).FindSolution
# 1183                   conjugate/utils.LoadY

# %%
sns.lineplot(data=df_cg_mem, x='Level', y='Cum%', hue='Detail')
plt.ylabel("Percentage of memory")
# Out:
# Text(0, 0.5, 'Percentage of memory')

# %% [markdown]
# ### Sylvester Method

# %%
df_mem = df[df['Type'] == 'memory']
top_commands = ['conjugate/solu.NewSylSolu', 'conjugate/utils.LoadY']
df_syl_mem = df_mem[(df_mem['Algorithm'] == 'syl') & (df['Detail'].isin(top_commands)) & (df['Level'] >= 5)]

# %%
sns.lineplot(data=df_syl_mem, x='Level', y='Cum%', hue='Detail')
plt.legend(['solu.NewSylSolu', 'utils.LoadY'])
plt.ylabel("Percentage of memory")
# Out:
# Text(0, 0.5, 'Percentage of memory')

# %%
df_time = df[df['Type'] == 'time']
top3_commands = ['conjugate/solu.(*DXOpe).cal', 'conjugate/solu.findNeighbors', 'conjugate/solu.NewSylSolu']
df_syl_time = df_time[(df_time['Algorithm'] == 'syl') & (df['Detail'].isin(top3_commands)) & (df['Level'] >= 4)]

# %%
sns.lineplot(data=df_syl_time, x='Level', y='Cum%', hue='Detail')
plt.legend(['solu.(*DXOpe).cal', 'solu.findNeighbors', 'solu.NewSylSolu'])
plt.ylabel("Percentage of time")
# Out:
# Text(0, 0.5, 'Percentage of time')

# %%
df_syl_time
# Out:
#       Type Algorithm Level   Flat   Flat%    Sum%     Cum   Cum%  \
# 546   time       syl     4   0.00   0.000  100.00   10.00  14.29
# 547   time       syl     4   0.00   0.000  100.00   10.00  14.29
# 584   time       syl     5   0.00   0.000  100.00   10.00   7.69
# 585   time       syl     5   0.00   0.000  100.00   10.00   7.69
# 586   time       syl     5   0.00   0.000  100.00   10.00   7.69
# 624   time       syl     6  30.00   4.170   75.00  290.00  40.28
# 628   time       syl     6  10.00   1.390   86.11  150.00  20.83
# 639   time       syl     6   0.00   0.000  100.00   20.00   2.78
# 715   time       syl     7   0.08   4.790   74.25    0.46  27.54
# 716   time       syl     7   0.04   2.400   76.65    0.17  10.18
# 745   time       syl     7   0.00   0.000  100.00    0.13   7.78
# 841   time       syl     8   0.77  10.590   57.91    4.17  57.36
# 844   time       syl     8   0.24   3.300   70.56    1.65  22.70
# 870   time       syl     8   0.01   0.140   93.12    0.48   6.60
# 927   time       syl     9   7.36  17.210   39.24   32.19  75.28
# 929   time       syl     9   2.18   5.100   61.53   14.01  32.76
# 955   time       syl     9   0.04   0.094   95.30    2.36   5.52
# 1013  time       syl    10  46.26  17.430   42.23  207.23  78.08
# 1015  time       syl    10  20.85   7.860   65.60  103.97  39.17
# 1038  time       syl    10   0.13   0.049   94.10   19.88   7.49
#
#                             Detail
# 546    conjugate/solu.(*DXOpe).cal
# 547   conjugate/solu.findNeighbors
# 584    conjugate/solu.(*DXOpe).cal
# 585      conjugate/solu.NewSylSolu
# 586   conjugate/solu.findNeighbors
# 624    conjugate/solu.(*DXOpe).cal
# 628   conjugate/solu.findNeighbors
# 639      conjugate/solu.NewSylSolu
# 715    conjugate/solu.(*DXOpe).cal
# 716   conjugate/solu.findNeighbors
# 745      conjugate/solu.NewSylSolu
# 841    conjugate/solu.(*DXOpe).cal
# 844   conjugate/solu.findNeighbors
# 870      conjugate/solu.NewSylSolu
# 927    conjugate/solu.(*DXOpe).cal
# 929   conjugate/solu.findNeighbors
# 955      conjugate/solu.NewSylSolu
# 1013   conjugate/solu.(*DXOpe).cal
# 1015  conjugate/solu.findNeighbors
# 1038     conjugate/solu.NewSylSolu
